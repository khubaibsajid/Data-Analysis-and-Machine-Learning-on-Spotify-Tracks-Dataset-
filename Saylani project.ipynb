# %% [markdown]
# # SMIT –DATA Science and Machine Learning Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
spotify = pd.read_csv('spotify.csv', encoding='ISO-8859-1')
spotify
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %% [markdown]
# # Load the Data

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
spotify.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
spotify.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
spotify['danceability_%'].describe()
# Out:
# count    953.00000
# mean      66.96957
# std       14.63061
# min       23.00000
# 25%       57.00000
# 50%       69.00000
# 75%       78.00000
# max       96.00000
# Name: danceability_%, dtype: float64

# %%
spotify['energy_%'].describe()
# Out:
# count    953.000000
# mean      64.279119
# std       16.550526
# min        9.000000
# 25%       53.000000
# 50%       66.000000
# 75%       77.000000
# max       97.000000
# Name: energy_%, dtype: float64

# %%
spotify['speechiness_%'].describe()
# Out:
# count    953.000000
# mean      10.131165
# std        9.912888
# min        2.000000
# 25%        4.000000
# 50%        6.000000
# 75%       11.000000
# max       64.000000
# Name: speechiness_%, dtype: float64

# %% [markdown]
# # Data Cleaning

# %%
spotify.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
spotify.isna().dropna().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
spotify.dropna(subset= ['key','in_shazam_charts'], inplace=True)

# %%
spotify.isna().sum()
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# in_shazam_charts        0
# bpm                     0
# key                     0
# mode                    0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# dtype: int64

# %%
names = spotify[['track_name','artist(s)_name','released_day']]

# %%
spotify = spotify.drop(columns=['track_name','artist(s)_name','released_day'])

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 817 entries, 0 to 952
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   artist_count          817 non-null    int64
#  1   released_year         817 non-null    int64
#  2   released_month        817 non-null    int64
#  3   in_spotify_playlists  817 non-null    int64
#  4   in_spotify_charts     817 non-null    int64
#  5   streams               817 non-null    object
#  6   in_apple_playlists    817 non-null    int64
#  7   in_apple_charts       817 non-null    int64
#  8   in_deezer_playlists   817 non-null    object
#  9   in_deezer_charts      817 non-null    int64
#  10  in_shazam_charts      817 non-null    object
#  11  bpm                   817 non-null    int64
#  12  key                   817 non-null    object
#  13  mode                  817 non-null    object
#  14  danceability_%        817 non-null    int64
# ...

# %%
for col in spotify.columns:
    unique_vals = spotify[col].nunique()
    print(f"{col}: {unique_vals} unique values")
# Out:
# artist_count: 8 unique values
# released_year: 46 unique values
# released_month: 12 unique values
# in_spotify_playlists: 756 unique values
# in_spotify_charts: 76 unique values
# streams: 814 unique values
# in_apple_playlists: 206 unique values
# in_apple_charts: 163 unique values
# in_deezer_playlists: 292 unique values
# in_deezer_charts: 31 unique values
# in_shazam_charts: 187 unique values
# bpm: 122 unique values
# key: 11 unique values
# mode: 2 unique values
# danceability_%: 71 unique values
# valence_%: 94 unique values
# energy_%: 78 unique values
# acousticness_%: 93 unique values
# instrumentalness_%: 36 unique values
# liveness_%: 66 unique values
# speechiness_%: 48 unique values

# %%
spotify['artist_count'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 817 entries, 0 to 952
# Series name: artist_count
# Non-Null Count  Dtype
# --------------  -----
# 817 non-null    int64
# dtypes: int64(1)
# memory usage: 12.8 KB

# %%
spotify['released_month'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 817 entries, 0 to 952
# Series name: released_month
# Non-Null Count  Dtype
# --------------  -----
# 817 non-null    int64
# dtypes: int64(1)
# memory usage: 12.8 KB

# %%
spotify['artist_count'] = spotify['artist_count'].astype('category')

# %%
spotify['artist_count'].head()
# Out:
# 0    2
# 1    1
# 2    1
# 3    1
# 4    1
# Name: artist_count, dtype: category
# Categories (8, int64): [1, 2, 3, 4, 5, 6, 7, 8]

# %%
spotify['released_month'].head()
# Out:
# 0    7
# 1    3
# 2    6
# 3    8
# 4    5
# Name: released_month, dtype: int64

# %%
spotify['released_month'] = spotify['released_month'].astype('category')

# %%
spotify['released_month'].head()
# Out:
# 0    7
# 1    3
# 2    6
# 3    8
# 4    5
# Name: released_month, dtype: category
# Categories (12, int64): [1, 2, 3, 4, ..., 9, 10, 11, 12]

# %%
spotify['mode'].head()
# Out:
# 0    Major
# 1    Major
# 2    Major
# 3    Major
# 4    Minor
# Name: mode, dtype: object

# %%
spotify['mode'] = spotify['mode'].apply(lambda x: 1 if x == 'Major' else 0)

# %%
spotify['mode'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# Name: mode, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# Correlation Heatmap:

# %%
plt.figure(figsize=(12,8))

sns.heatmap(spotify.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Coorelation Heatmap')
plt.show()

# %% [markdown]
# Popularity Disttribution:

# %%
sns.histplot(spotify['acousticness_%'], bins=30, kde=True, color='green')
plt.title('Distribution of Popularity')

plt.xlabel('Popularity')
plt.ylabel('Count')

plt.show()

# %%
sns.scatterplot(data=spotify, x='danceability_%', y='acousticness_%', alpha=0.5)
plt.title('Danceability v Popularity')
plt.show()

# %%
sns.boxplot(data=spotify, x='mode', y='acousticness_%')
plt.title('Popularity by MODE')
plt.show()

# %% [markdown]
# Count of songs per key:

# %%
sns.countplot(data=spotify, x ='key')
plt.title("Numeber of songs per musical key")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Popularity by Release Month:

# %%
sns.boxenplot(data=spotify, x='released_month',y='acousticness_%')
plt.title('Popularity y release Month')
plt.show()

# %%
sns.pairplot(spotify[['acousticness_%', 'energy_%', 'liveness_%','danceability_%']])
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
spotify['is_popular'] = (spotify['acousticness_%'] > 60).astype(int)

# %%
spotify['is_popular'].sum()
# Out:
# 114

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 817 entries, 0 to 952
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   artist_count          817 non-null    category
#  1   released_year         817 non-null    int64
#  2   released_month        817 non-null    category
#  3   in_spotify_playlists  817 non-null    int64
#  4   in_spotify_charts     817 non-null    int64
#  5   streams               817 non-null    object
#  6   in_apple_playlists    817 non-null    int64
#  7   in_apple_charts       817 non-null    int64
#  8   in_deezer_playlists   817 non-null    object
#  9   in_deezer_charts      817 non-null    int64
#  10  in_shazam_charts      817 non-null    object
#  11  bpm                   817 non-null    int64
#  12  key                   817 non-null    object
#  13  mode                  817 non-null    int64
#  14  danceability_%        817 non-null    int64
# ...

# %%
if spotify['streams'].dtype =='object':
    spotify['streams'] = spotify['streams'].str.replace(',','')
    spotify['streams'] = pd.to_numeric(spotify['streams'],error='coerce')

# %%
scaler = MinMaxScaler()
spotify['energy_norm'] = scaler.fit_transform(spotify[['energy_%']])

# %%
spotify['energy_loudness'] = (spotify['liveness_%'] + spotify['energy_norm']) / 2

# %%
print(spotify[['acousticness_%', 'is_popular', 'energy_%', 'energy_loudness']].head())
# Out:
#    acousticness_%  is_popular  energy_%  energy_loudness
# 0              31           0        83         4.415663
# 1               7           0        74         5.361446
# 2              17           0        53        15.734940
# 3              11           0        72         5.849398
# 4              14           0        80         5.897590

# %% [markdown]
# # Spilitting the Data:

# %%
from sklearn.model_selection import train_test_split

# %%
X = spotify.drop('is_popular', axis=1)
y = spotify['is_popular']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=42)

# %%
print(f"Train shape: {X_train.shape}  Test shape: {X_test.shape}")
# Out:
# Train shape: (653, 23)  Test shape: (164, 23)

# %% [markdown]
# # Applying a machine learning Model :

# %% [markdown]
# ### Logistic Regression:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
spotify = spotify.dropna()

# %%
from sklearn.linear_model import LogisticRegression

logR = LogisticRegression(max_iter=1000)
logR.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = logR.predict(X_test)

# %% [markdown]
# # Model Evalution:

# %%
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("\nClassification Report : ", classification_report(y_test, y_pred))
print("\nConfusion Matrix : ",confusion_matrix(y_test, y_pred))
# Out:
# Accuracy:  0.8475609756097561
#
# Classification Report :                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92       139
#            1       0.00      0.00      0.00        25
#
#     accuracy                           0.85       164
#    macro avg       0.42      0.50      0.46       164
# weighted avg       0.72      0.85      0.78       164
#
#
# Confusion Matrix :  [[139   0]
#  [ 25   0]]
# C:\Users\khank\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# %%
y_probs = logR.predict_proba(X_test)[:,1]

# %%
#Calcluate FPR,TPR and Thresholds

fpr, tpr, thresholds = roc_curve(y_test, y_probs)

# %%
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='Logistic Regression')
plt.plot([0,1],[0,1], linestyle='--', color='gray')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend()
plt.grid(True)
plt.show()

# %%
auc = roc_auc_score(y_test, y_probs)
print(f"AUC score: {auc: .4f}")
# Out:
# AUC score:  0.5381

# %% [markdown]
# # Model Imporvement

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### GridSearchCv

# %%
param_grid = {
    'C' : [0.01, 0.1, 1, 10],
    'penalty': ['l1', 'l2'],
    'solver' : ['liblinear']
}

logR = LogisticRegression(max_iter = 1000)

grid = GridSearchCV(logR, param_grid, cv=5, scoring='roc_auc')
grid.fit(X_train, y_train)

print('Best Parameters:', grid.best_params_)
print('Best AUC Score:', grid.best_score_)
# Out:
# Best Parameters: {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
# Best AUC Score: 0.9988095238095237

# %% [markdown]
# # The End.
